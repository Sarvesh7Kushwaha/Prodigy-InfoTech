# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('WorldBank.csv') # file API_SP.POP.TOTL_DS2_en_csv_v2_85 is renamed WorldBank

# %%
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 259                       Kosovo          XKX  Population, total
# 260                  Yemen, Rep.          YEM  Population, total
# 261                 South Africa          ZAF  Population, total
# 262                       Zambia          ZMB  Population, total
# 263                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code       1960       1961       1962       1963       1964  \
# 0      SP.POP.TOTL      54608      55811      56682      57475      58178
# ...

# %%
df.shape
# Out:
# (264, 69)

# %%
df["Growth 1960-2022"] = df["1960"] - df["2022"]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=264, step=1)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Growth 2000-2010', 'Growth 1960-2022'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country Name        object
# Country Code        object
# Indicator Name      object
# Indicator Code      object
# 1960                 int64
#                      ...
# 2020                 int64
# 2021                 int64
# 2022                 int64
# Growth 2000-2010     int64
# Growth 1960-2022     int64
# Length: 69, dtype: object

# %%
df.nunique()
# Out:
# Country Name        264
# Country Code        264
# Indicator Name        1
# Indicator Code        1
# 1960                260
#                    ...
# 2020                262
# 2021                262
# 2022                262
# Growth 2000-2010    262
# Growth 1960-2022    262
# Length: 69, dtype: int64

# %%
df.count()
# Out:
# Country Name        264
# Country Code        264
# Indicator Name      264
# Indicator Code      264
# 1960                264
#                    ...
# 2020                264
# 2021                264
# 2022                264
# Growth 2000-2010    264
# Growth 1960-2022    264
# Length: 69, dtype: int64

# %%
df["Growth 1960-2022"]
# Out:
# 0         -51837
# 1     -590166553
# 2      -32506305
# 3     -393074580
# 4      -30231792
#          ...
# 259      -814985
# 260    -28154155
# 261    -43373444
# 262    -16898245
# 263    -12514227
# Name: Growth 1960-2022, Length: 264, dtype: int64

# %%
df_sorted = df.sort_values(by="Growth 1960-2022", ascending=False)

# %%
df_sorted
# Out:
#             Country Name Country Code     Indicator Name Indicator Code  \
# 246              Ukraine          UKR  Population, total    SP.POP.TOTL
# 21              Bulgaria          BGR  Population, total    SP.POP.TOTL
# 101              Hungary          HUN  Population, total    SP.POP.TOTL
# 99               Croatia          HRV  Population, total    SP.POP.TOTL
# 144               Latvia          LVA  Population, total    SP.POP.TOTL
# ..                   ...          ...                ...            ...
# 102            IBRD only          IBD  Population, total    SP.POP.TOTL
# 155        Middle income          MIC  Population, total    SP.POP.TOTL
# 139  Low & middle income          LMY  Population, total    SP.POP.TOTL
# 103     IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 257                World          WLD  Population, total    SP.POP.TOTL
#
#            1960        1961        1962        1963        1964        1965  \
# ...

# %%
df_sorted_fr=df_sorted

# %%
for i in range(0, len(df_sorted), 20):
    df_subset = df_sorted_fr.iloc[i:i+20]
   
    plt.figure(figsize=(10,8))
    plt.barh(df_subset["Country Name"], df_subset["Growth 1960-2022"], color="skyblue")
    plt.xlabel("Population Growth from 1960 to 2022")
    plt.ylabel("Country Name")
    plt.title(f"Population Growth from 1960 to 2022 by Country (Countries {i+1} to {min(i+20, len(df_sorted_fr))})")
    plt.tight_layout()
    plt.show()

# %%
for i in range(0, len(df_sorted_1), 20):
    df_subset = df_sorted_1.iloc[i:i+20]  
    
    plt.figure(figsize=(12, 10))
    bars_1960 = plt.barh(df_subset["Country Name"], df_subset["1960"], color='pink', label='Population in 1960 (simulated)')
    bars_growth = plt.barh(df_subset["Country Name"], df_subset["Growth 1960-2022"], left=df_subset["1960"], color='lightblue', label='Growth 1960-2022 (simulated)')
    
    plt.xlabel("Population + Growth")
    plt.ylabel("Country")
    plt.title(f"Population in 1960 and Growth by 2022 for Countries {i+1} to {min(i+20, len(df_sorted_1))}")
    plt.legend()

    plt.tight_layout()
    plt.show()
